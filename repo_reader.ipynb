# %%
import networkx as nx
import matplotlib.pyplot as plt
import os
import ast
import pprint
from collections import defaultdict
import tkinter as tk
from tkinter import filedialog
import logging
import warnings
import ast
import openai
import callgpt
from callgpt import Ask

logger = logging.getLogger(__name__)

# Catch warnings
def fxn():
    warnings.warn("deprecated", DeprecationWarning)

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    fxn()

def open_file(filepath):
    with open(filepath, 'r', encoding='utf-8') as infile:
        return infile.read()

# os.chdir(directory)
warnings.filterwarnings("ignore")

def clone_github_repo(repo_url):
    temp_dir = tempfile.mkdtemp()
    Repo.clone_from(repo_url, temp_dir)
    return temp_dir

def find_python_files(path):
    python_files = []
    for root, _, files in os.walk(path):
        for file in files:
            if file.endswith(".py"):
                python_files.append(os.path.join(root, file))
    return python_files

def analyze_directory(directory):
    python_files = find_python_files(directory)
    file_analysis = {}

    for file_path in python_files:
        file_info = extract_info_from_file(file_path)
        file_analysis[file_path] = file_info

    return file_analysis

def extract_info_from_file(file_path):
    with open(file_path, "r", encoding="utf-8") as f:
        file_content = f.read()

    tree = ast.parse(file_content)
    file_info = {
        "functions": [],
        "imports": [],
        "variables": set(),
    }

    for node in ast.walk(tree):
        if isinstance(node, ast.FunctionDef):
            file_info["functions"].append(node.name)
        elif isinstance(node, ast.Import) or isinstance(node, ast.ImportFrom):
            for alias in node.names:
                file_info["imports"].append(alias.name)
        elif isinstance(node, ast.Assign):
            for target in node.targets:
                if isinstance(target, ast.Name):
                    file_info["variables"].add(target.id)

    file_info["variables"] = list(file_info["variables"])
    return file_info

def visualize_connections(analysis):
    G = nx.DiGraph()

    for file_path, info in analysis.items():
        G.add_node(file_path)

        for imported_module in info["imports"]:
            G.add_node(imported_module)
            G.add_edge(file_path, imported_module)

    plt.figure(figsize=(10, 10))
    pos = nx.spring_layout(G)
    nx.draw(G, pos, with_labels=True, node_size=2000, font_size=10, font_weight="bold")
    plt.show()

def generate_textual_summary(analysis):
    summary = []

    for file_path, info in analysis.items():
        summary.append(f"File: {file_path}\n")

        if info["imports"]:
            summary.append("Imports:")
            for imported_module in info["imports"]:
                summary.append(f"  - {imported_module}")
            summary.append("\n")

        if info["functions"]:
            summary.append("Functions:")
            for function_name in info["functions"]:
                summary.append(f"  - {function_name}")
            summary.append("\n")

        if info["variables"]:
            summary.append("Variables:")
            for variable_name in info["variables"]:
                summary.append(f"  - {variable_name}")
            summary.append("\n")

    return "\n".join(summary)

def main():
    # repo_url = input("Input url") # Replace with the GitHub repository URL
    # local_repo_path = clone_github_repo(repo_url)
    dirc = filedialog.askdirectory()
    analysis = analyze_directory(dirc)
    # pprint.pprint(analysis)
    visualize_connections(analysis)
    summary = generate_textual_summary(analysis)
    prompt = "You are an exceptional programmer, like Linus Torvalds. You can understand entire codebases and the interrelationships. Please generate a perfectly detailed summary of the code, its structure and possible uses given the following filenames and functions:\n"+str(summary)+"\n\n:"
    chatbot = Ask()
    response = chatbot.gpt_smart(prompt)
    # print(response)

    # Loop to handle follow-up questions
    while True:
        user_question = input("\nEnter your follow-up question or type 'exit' to quit: ").strip()
        if user_question.lower() == 'exit':
            break

        # Call GPT chatbot with the follow-up question
        response = chatbot.gpt_smart(user_question)
        # print(response)

if __name__ == "__main__":
    main()
# Out:
# 2023-04-15 22:14:02.044 Python[23028:4031949] +[CATransaction synchronize] called within transaction
# 2023-04-15 22:14:04.352 Python[23028:4031949] +[CATransaction synchronize] called within transaction
# 2023-04-15 22:14:04.396 Python[23028:4031949] +[CATransaction synchronize] called within transaction
# 2023-04-15 22:14:04.531 Python[23028:4031949] +[CATransaction synchronize] called within transaction
# 2023-04-15 22:14:04.645 Python[23028:4031949] +[CATransaction synchronize] called within transaction
# User: You are an exceptional programmer, like Linus Torvalds. You can understand entire codebases and the interrelationships. Please generate a perfectly detailed summary of the code, its structure and possible uses given the following filenames and functions:
# File: /Users/rohit/Library/CloudStorage/OneDrive-Personal/SM_RK Shared folder/PoY Collaboration/Shruti/Run_snapshot_AnalysisFunctions_v3.py
#
# Imports:
#   - In
#   - IN
#   - time
#   - SnapshotBrowsingAnalysis
#   - MatchDemographics
#   - CombineScrapedProducts
#   - GenerateRelevantReviewFileForClient
#   - RelevantPatternMatch
#   - RelevantSimilarityIndexNewVersion
#   - pandas
#   - os
#   - csv
#   - warnings
#   - glob
#   - sqlalchemy
#   - create_engine
#   - StringIO
#   - init
#   - Fore
#   - Back
#   - Style
#   - psycopg2
#   - readline
#   - load_dotenv
#   - Path
#   - SentenceTransformer
#   - util
#   - Pool
#   - urllib.parse
#   - stopwords
#   - logging
#   - fuzz
#   - process
#   - repeat
#
#
# Functions:
#   - correct_participantid
#   - SwitchFunctionality
#   - writeDataToSql
#
#
# Variables:
#   - relevantFinalDataToCsv
#   - tiktokData
#   - clientSearchTermFileRead
#   - urlPath
#   - outlierDataList
#   - schemaName
#   - DomainStartBuyWord
#   - name
#   - DomainProductSplit
#   - csvfilemaster
#   - exampleFileTest
#   - DomainStartWordPattern2
#   - urlPathFileName
#   - dataFolderName
#   - analysisData
#   - pathMapBeforeVisit
#   - quoraData
#   - sessionAnalysisReturnData
#   - filePrefix
#   - relevantMapByClient
#   - password
#   - relevantAnalysisData
#   - masData
#   - DomainDelivery
#   - DomainCheckoutTitle
#   - data
#   - tableRunInput
#   - pathMap
#   - filterReturnData
#   - hostCleaningFile
#   - allSearchTermsList
#   - searchTermsClientData
#   - relevantMapPoy
#   - dataset
#   - instagramHashtags
#   - hostPatternMapFile
#   - searchProductData
#   - DomainPickUp
#   - sourceVal
#   - allTableNames
#   - brosingfilename
#   - keywordFilename
#   - rds_host
#   - exampleFileKeyword
#   - modifiedNo
#   - DomainStartCartWord
#   - exampleDataTest
#   - sessionDataList
#   - writeAllData
#   - final_data_summary
#   - DomainStartCategoryWord
#   - relevantFileName
#   - outlierAnalysisReturnData
#   - colDf
#   - port
#   - relevantMap
#   - participantPercentage
#   - dfList
#   - tablePrefix
#   - hideoutTitleMapFile
#   - tableRunMapDict
#   - instagramProfiles
#   - visitVsPurchaseReturnData
#   - translationFlag
#   - DomainStartword
#   - DomainCheckoutUrl
#   - temp
#   - dotenv_path
#   - timeSpentDataList
#   - engine
#   - relevantMapClient
#   - relevantMapByPoy
#   - newDf
#   - cur
#   - con
#   - relevantMapFile
#   - modifiedMaybe
#   - exampleReaderTest
#   - transData
#   - DomainsInHostPatterns
#   - df
#   - DomainProduct
#   - categoryMapFile
#   - csvfilenameTest
#   - urlPageBeforePath
#   - redditData
#   - DomainStartWordPattern3
#   - relevantAnalyzedData
#   - HigherRange
#   - exampleReaderKeyword
#   - DomainStartWordPattern4
#   - productMapFile
#   - switchArgument
#   - linkedinData
#   - dirname
#   - targetVal
#   - columnNames
#   - translationRequired
#   - pool
#   - dataForIndependentFunctions
#   - rawData
#   - db_name
#   - modifiedYes
#   - relevantUrlPathData
#   - bingeMap
#   - formatChanged
#   - instagramActivity
#   - allFuncVariables
#   - lowerRange
#   - variableData
#   - summary_df_list
#   - allFuncTableNames
#   - relevantHost
#   - relevantHostList
#   - bingeMapFile
#   - relevantReturnData
#   - exampleDataKeyword
#   - facebookData
#   - relevantMapData
#   - searchMapFile
#   - csvfilenameKeyword
#   - urlPathFile
#   - combined_data
#   - twitterData
#   - coSearchTermsReturnData
#   - pinterestData
#   - switchDictionary
#   - variableDataGroup
#   - browsing_file
#   - prodCatMapFile
#   - DomainStartSearchword
#   - timeSpentReturnData
#   - youtubeData
#   - envPath
#
#
# File: /Users/rohit/Library/CloudStorage/OneDrive-Personal/SM_RK Shared folder/PoY Collaboration/Shruti/snapshot_AnalysisFunctions_v3.py
#
# Imports:
#   - time
#   - re
#   - shutil
#   - tldextract
#   - pandas
#   - urllib.parse
#   - math
#   - os
#   - numpy
#   - datetime
#   - glob
#   - init
#   - Fore
#   - GoogleTranslator
#   - fuzz
#   - process
#   - warnings
#   - logging
#   - swifter
#   - urllib.parse
#   - stopwords
#   - SentenceTransformer
#   - util
#   - repeat
#
#
# Functions:
#   - removeNonAscii
#   - subtract
#   - Redirect
#   - RedirectModification
#   - MatchDemographics
#   - GenerateRelevantReviewFileForClient
#   - CombineScrapedProducts
#   - translateTitle
#   - generate_embeding
#   - clean_data
#   - replace_host
#   - replace_host_group
#   - similarity_score
#   - RelevantSimilarityIndexNewVersion
#   - RelevantPatternMatch
#   - KeywordPatternMatch
#   - category_matched
#   - __init__
#   - DataFormatting
#   - Domains
#   - HostCategorization
#   - Transition
#   - HostBounce
#   - UrlPath
#   - TimeSpent
#   - TimeSpentInSec
#   - OverviewGeneric
#   - Redirects
#   - SearchTerms
#   - ProductsPathMap
#   - Products
#   - PageBeforeProductVisits
#   - PageBeforeRelevantVisits
#   - RelevantHostPattern
#   - PageBeforeAfterRelevantVisits
#   - BuySession
#   - HostSession
#   - OrderJourney
#   - HideoutTitleMap
#   - Relevant
#   - RelevantHostFirstVisitInSession
#   - Accounts
#   - FirstLastVisit
#   - DaysBeforePurchase
#   - TimeSpentAggregation
#   - Instagram
#   - Shopping_Filter
#   - PrePostDomains
#   - VisitVsPurchase
#   - CorrelatedSearchTerms
#   - AdClicks
#   - OutlierDetection
#   - SessionOutliers
#   - facebookDetailActivity
#   - youtubeDetailActivity
#   - redditDetailActivity
#   - LinkedInActivity
#   - tiktokDetailActivity
#   - twitterDetailActivity
#   - pinterestDetailActivity
#   - quoraDetailActivity
#   - FacebookCleaning
#   - YoutubeCleaning
#   - RedditCleaning
#   - LinkedinCleaning
#   - TiktokCleaning
#   - TwitterCleaning
#   - PinterestCleaning
#   - WebsiteCleaning
#   - relevant_summary
#   - FindLengthSubstring
#
#
# Variables:
#   - relevantFinalDataToCsv
#   - tiktokData
#   - marketRegex
#   - regVar
#   - keyword_matched
#   - relevantMatchData
#   - buy_host_df
#   - categorykeywordUrl
#   - adultList
#   - preSearchIndex
#   - checkList
#   - timeSpentData
#   - data_copy
#   - df1
#   - buy_host_last_activity
#   - bingeAnalysisData
#   - noOfSessionData
#   - relevantHosts
#   - prodCatList
#   - filter1
#   - cond4
#   - cartDict
#   - cond3
#   - preMatchIndexList
#   - totalParticipantsInDemographics
#   - lastIndexSearch
#   - categoryValueForColumn
#   - participantRelevance
#   - quoraData
#   - relevantDomainSessionTime
#   - domDateList
#   - excludeFolderName
#   - replaceValues
#   - relevantRegex
#   - firstIndexSearch
#   - reddit
#   - relevantClientFormat
#   - topHashtags
#   - wordColumnList
#   - masData
#   - filter4
#   - buy_host_agg
#   - instagramData
#   - search_index_list
#   - data
#   - dayBefore
#   - keywordPart
#   - prepostFileName
#   - participantDfList
#   - columnsToRemove
#   - cleaningVariables
#   - allSearchTermsList
#   - buy_session_participantd_df
#   - productCategory
#   - sessionList
#   - max_value_keyword_list
#   - scrapeHost
#   - preRelevantIndexList
#   - files
#   - dataset
#   - prodIndexList
#   - filter6
#   - shopTagFile
#   - youtubeFileName
#   - participantIdList
#   - instagramHashtags
#   - searchProductData
#   - first_last_agg
#   - dateIndex
#   - redditReplaceDict
#   - relHostIndexes
#   - translatedText
#   - fbData
#   - appendColumnList
#   - lastTime
#   - lengthOfColumns
#   - finalDomainData
#   - session_data
#   - searchData
#   - currTimeZero
#   - filter5
#   - fileName
#   - columnsToConvert
#   - relevantIndex
#   - search_relevant_df
#   - content_relevant_df
#   - outlierAnalysisData
#   - categoryKeywordFinalUrl
#   - search_setp2_index_to_remove
#   - relevantFileName
#   - folderName
#   - domainKeywordType
#   - preIndex
#   - domData
#   - participantPercentage
#   - buyDf
#   - buy_host_list
#   - instagramProfiles
#   - currTime
#   - prev
#   - postMatchIndexList
#   - keyword_dataframe_sorted
#   - nonOther
#   - stopwords_to_remove
#   - search_step2_index_list
#   - tiktokReplaceDict
#   - nonOtherList
#   - perDayTime
#   - sdata
#   - keyword_list
#   - keyword_dataframe
#   - indexList
#   - category_relevant_df
#   - index1
#   - temp
#   - shop_relevant_df
#   - session_bounce_data
#   - domListClient
#   - keyword_list_encoded
#   - scrapeProductFolder
#   - marketList
#   - relevant_participantd_df
#   - prepostRelevantData
#   - finVisitPurchaseDf
#   - timeSpent_return_data
#   - total_participants_df
#   - activityKeywords
#   - filterDomains
#   - onlineComListRegex
#   - regexList
#   - homeList
#   - onlineComList
#   - relevant_summary_data
#   - potentialOutliers
#   - product_relevant_df
#   - finalData
#   - notPresentId
#   - i
#   - relHosts
#   - notMatchFilename
#   - host_group_to_replace
#   - lastIndex
#   - topProfiles
#   - filter3
#   - search_setp1_index_to_remove
#   - lastCurrTime
#   - categoryKeywordFinalParticipants
#   - userAuthList
#   - ovelallAnalysis
#   - domListRegex
#   - mask2
#   - newfn
#   - PrevTime
#   - finalFileName
#   - firstIndex
#   - hostCatMap
#   - keyword_match_list
#   - prePostData
#   - nonUserList
#   - domList
#   - sessionAnalysisData
#   - indexValues
#   - urlDfList
#   - otherData
#   - rawDataParticipantsPresentInDemographics
#   - kijijiData
#   - prodIndex
#   - csvfilename
#   - ts
#   - similarity_score
#   - HigherRange
#   - cart
#   - buyRegex
#   - val
#   - storeList
#   - matchIndex
#   - lastHost
#   - urlDf
#   - youtubeReplaceDict
#   - relevant_hosts
#   - cat_list_matched
#   - relevantDomList
#   - scrapeHostList
#   - cond2
#   - linkedData
#   - offerList
#   - search_step1_index_list
#   - lastDomName
#   - first_last_agg_summary
#   - filter2
#   - hostBuyDf
#   - participantDf
#   - dirname
#   - categorizedData
#   - reviewList
#   - finalAnalysisData
#   - postRelevantIndexList
#   - sessionDomainsData
#   - existing_data
#   - dataForIndependentFunctions
#   - finalVisits
#   - typeList
#   - finData
#   - purchaseJourneyList
#   - diffList
#   - lastDate
#   - instagramActivity
#   - lastHostInd
#   - postSearchIndex
#   - pinterestDict
#   - model_used
#   - lowerRange
#   - cond1
#   - domainData
#   - path
#   - xlsxfilename
#   - domainIndex
#   - journeyNumber
#   - participantLevelAnalysis
#   - non_buy_session_participantd_df
#   - twitterReplaceDict
#   - relevantReturnData
#   - notPresentDemoId
#   - lastHostGroup
#   - firstRelVisit
#   - adultListRegex
#   - mask1
#   - userProfile
#   - hosts_to_replace
#   - searchCombData
#   - df2
#   - regexName
#   - prodBeforeData
#   - relSessionList
#   - keywordUrl
#   - relevantDataFinalCount
#   - relevant_summary_df
#   - categorykeywordParticipants
#   - buyRegexDomain
#   - finalSessionData
#   - twitterData
#   - lastRelVisit
#   - categoryKeywordData
#   - fbReplaceDict
#   - hostSession
#   - index2
#   - pinterestData
#   - max_value
#   - keywordFinalFile
#   - replaceDict
#   - merged
#   - prodFileName
#   - searchDataMerge
#   - relevantClientFileName
#   - postIndex
#   - timeSpentReturnData
#   - non_useful_keywords
#   - modList
#   - te
#   - youtubeData
#   - buy_host_first_activity
#   - buy_host
#   - matched_items
#
#
#
# :
# SmartGPT: Unfortunately, as an AI language model, I am not able to generate a perfectly detailed summary of the code structure and possible uses with just filenames and functions. To accurately describe a codebase, I would need to have access to the actual code and related documentation. Without access to that information, I cannot provide a useful summary.
# User: Can you tell me an idea of how the functions in the code flows?
# SmartGPT: Certainly, here is a brief overview of how the functions in the code may flow:
#
# 1. The code imports several packages and libraries necessary for its execution, including pandas, regex, sqlalchemy, and logging.
# 2. The code defines several functions for processing and analyzing data, including functions for formatting data, analyzing time spent, and conducting outlier analysis.
# 3. The code also includes functions for cleaning and processing data from specific social media platforms, including Twitter, LinkedIn, and Reddit.
# 4. The code defines several variables, which are used throughout the program to store data and perform calculations.
# 5. The main file, "Run_snapshot_AnalysisFunctions_v3.py", contains several functions to drive the analysis process. These functions are called in a specific sequence, with each function passing its results to the next function in the chain.
# 6. The code starts by reading in data from specific files, then proceeds to analyze and process that data using various analysis and processing functions.
# 7. Finally, the code outputs the results of the analysis to specific files, including CSV and SQL files.
#
# Overall, the code appears to be organized around a modular structure, with clearly defined components for data input, data processing, and data output. The specific sequence of functions called in the main file appears to be designed to systematically analyze data and output useful analysis results.
# User: What actual data does the code embed and later index, so that it can be later retrieved to analyse for similarity?
# SmartGPT: Unfortunately, with the information provided in the question, it is difficult to determine exactly what data the code embeds and indexes for later retrieval and analysis. However, based on the functions and variables listed in the code, there are a few possibilities:
#
# 1. The code uses the function "GenerateRelevantReviewFileForClient" to generate a relevant review file for a specific client. This function may embed and index data related to relevant reviews for that client, which could later
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# Cell In[2], line 146
#     143         # print(response)
#     145 if __name__ == "__main__":
# --> 146     main()
#
# Cell In[2], line 142, in main()
#     139     break
#     141 # Call GPT chatbot with the follow-up question
# --> 142 response = chatbot.gpt_smart(user_question)
#
# File ~/Library/CloudStorage/OneDrive-Personal/SM_RK Shared folder/Coding_Analysis/gpt_search/callgpt.py:118, in Ask.gpt_smart(self, prompt)
#     115 user_input = prompt
#     116 scholar_gpt_messages.append({"role": "user", "content": user_input})
# --> 118 response = openai.ChatCompletion.create(
#     119     model="gpt-3.5-turbo",
#     120     messages=scholar_gpt_messages
#     121 )
#     123 model_response = response.choices[0].message.content
#     124 self.messages.append({"role": "user", "content": user_input})
#
# File /Library/Python/3.9/site-packages/openai/api_resources/chat_completion.py:25, in ChatCompletion.create(cls, *args, **kwargs)
#      23 while True:
#      24     try:
# ---> 25         return super().create(*args, **kwargs)
#      26     except TryAgain as e:
#      27         if timeout is not None and time.time() > start + timeout:
#
# File /Library/Python/3.9/site-packages/openai/api_resources/abstract/engine_api_resource.py:153, in EngineAPIResource.create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     127 @classmethod
#     128 def create(
#     129     cls,
#    (...)
#     136     **params,
#     137 ):
#     138     (
#     139         deployment_id,
#     140         engine,
#    (...)
#     150         api_key, api_base, api_type, api_version, organization, **params
#     151     )
# --> 153     response, _, api_key = requestor.request(
#     154         "post",
#     155         url,
#     156         params=params,
#     157         headers=headers,
#     158         stream=stream,
#     159         request_id=request_id,
#     160         request_timeout=request_timeout,
#     161     )
#     163     if stream:
#     164         # must be an iterator
#     165         assert not isinstance(response, OpenAIResponse)
#
# File /Library/Python/3.9/site-packages/openai/api_requestor.py:226, in APIRequestor.request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     205 def request(
#     206     self,
#     207     method,
#    (...)
#     214     request_timeout: Optional[Union[float, Tuple[float, float]]] = None,
#     215 ) -> Tuple[Union[OpenAIResponse, Iterator[OpenAIResponse]], bool, str]:
#     216     result = self.request_raw(
#     217         method.lower(),
#     218         url,
#    (...)
#     224         request_timeout=request_timeout,
#     225     )
# --> 226     resp, got_stream = self._interpret_response(result, stream)
#     227     return resp, got_stream, self.api_key
#
# File /Library/Python/3.9/site-packages/openai/api_requestor.py:619, in APIRequestor._interpret_response(self, result, stream)
#     611     return (
#     612         self._interpret_response_line(
#     613             line, result.status_code, result.headers, stream=True
#     614         )
#     615         for line in parse_stream(result.iter_lines())
#     616     ), True
#     617 else:
#     618     return (
# --> 619         self._interpret_response_line(
#     620             result.content.decode("utf-8"),
#     621             result.status_code,
#     622             result.headers,
#     623             stream=False,
#     624         ),
#     625         False,
#     626     )
#
# File /Library/Python/3.9/site-packages/openai/api_requestor.py:682, in APIRequestor._interpret_response_line(self, rbody, rcode, rheaders, stream)
#     680 stream_error = stream and "error" in resp.data
#     681 if stream_error or not 200 <= rcode < 300:
# --> 682     raise self.handle_error_response(
#     683         rbody, rcode, resp.data, rheaders, stream_error=stream_error
#     684     )
#     685 return resp
#
# InvalidRequestError: This model's maximum context length is 4097 tokens. However, your messages resulted in 4113 tokens. Please reduce the length of the messages.
