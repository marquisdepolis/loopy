# %%
# !pip install googlesearch-python
# !pip install requests
from googlesearch import search
import openai
import requests
import os
import tkinter as tk
from tkinter import filedialog
from bs4 import BeautifulSoup
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: googlesearch-python in /Users/rohit/Library/Python/3.9/lib/python/site-packages (1.1.0)
# Requirement already satisfied: beautifulsoup4==4.9.3 in /Users/rohit/Library/Python/3.9/lib/python/site-packages (from googlesearch-python) (4.9.3)
# Requirement already satisfied: requests==2.25.1 in /Users/rohit/Library/Python/3.9/lib/python/site-packages (from googlesearch-python) (2.25.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/rohit/Library/Python/3.9/lib/python/site-packages (from beautifulsoup4==4.9.3->googlesearch-python) (2.3.2.post1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/rohit/Library/Python/3.9/lib/python/site-packages (from requests==2.25.1->googlesearch-python) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/rohit/Library/Python/3.9/lib/python/site-packages (from requests==2.25.1->googlesearch-python) (3.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/rohit/Library/Python/3.9/lib/python/site-packages (from requests==2.25.1->googlesearch-python) (1.26.14)
# Requirement already satisfied: idna<3,>=2.5 in /Users/rohit/Library/Python/3.9/lib/python/site-packages (from requests==2.25.1->googlesearch-python) (2.10)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: requests in /Users/rohit/Library/Python/3.9/lib/python/site-packages (2.25.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/rohit/Library/Python/3.9/lib/python/site-packages (from requests) (3.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/rohit/Library/Python/3.9/lib/python/site-packages (from requests) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/rohit/Library/Python/3.9/lib/python/site-packages (from requests) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /Users/rohit/Library/Python/3.9/lib/python/site-packages (from requests) (2.10)

# %%
def ask_gpt():
    your_question = input("Input what you are curious about: ")
    with open("openai_api_key.txt", "r") as f:
        openai.api_key = f.read().strip()

    query1 = []
    google_it = f"What are the key terms you can extract from this query that, if searched, will help find the answers to {your_question}"
    model1 = "text-davinci-003"
    params1 = {
        "prompt": google_it,
        "temperature": 0.5,
        "max_tokens": 100,
        "top_p": 1,
        "frequency_penalty": 0,
        "presence_penalty": 0
    }
    query1 = openai.Completion.create(engine=model1, **params1)
    print(query1.choices[0].text.strip())
    google_it = f"Return exactly one Google search query, phrased as a question, I could Google to find information regarding {your_question}"
    model1 = "text-davinci-003"
    params1 = {
        "prompt": google_it,
        "temperature": 0.5,
        "max_tokens": 100,
        "top_p": 1,
        "frequency_penalty": 0,
        "presence_penalty": 0
    }
    query2 = openai.Completion.create(engine=model1, **params1)
    query2

    return query1, query2

# %%
def clean_query(query1, query2):
    query = query2.choices[0].text.strip()
    return query

# %%
def iterate_google(query):
    # Iterate over the search results and append each URL to the list
    # programmatically search Google
    import requests
    import sys
    import os
    
    def open_file(filepath):
        with open(filepath, 'r', encoding='utf-8') as infile:
            return infile.read()
    
    directory = filedialog.askdirectory("Choose the folder with Google API files")
    os.chdir(directory)

    # API KEY from: https://developers.google.com/custom-search/v1/overview
    API_KEY = open_file('google_api_key.txt')
    # get your Search Engine ID on your CSE control panel
    SEARCH_ENGINE_ID = open_file('google_searchengine_id.txt')
    print(API_KEY)
    print(SEARCH_ENGINE_ID)
    try:
        page = int(sys.argv[2])
        # make sure page is positive
        assert page > 0
    except:
        print("Page number isn't specified, defaulting to 1")
        page = 1
    # constructing the URL
    # doc: https://developers.google.com/custom-search/v1/using_rest
    # calculating start, (page=2) => (start=11), (page=3) => (start=21)
    # for some reason it's best to copy paste the query here
    # query = "{query}"
    print(query)
    start = (page - 1) * 10 + 1
    url = f"https://www.googleapis.com/customsearch/v1?cx={SEARCH_ENGINE_ID}&key={API_KEY}&q={query}&start={start}"
    print(url)
    # make the API request
    response = requests.get(url)
    print("Status code:", response.status_code)
    print("Response content:", response.text)
    data = response.json()
    # get the result items
    search_items = data.get("items")
    print(search_items)
    if search_items is None:
        print("No search results found")
        exit()
    # iterate over 10 results found
    links = []
    for i, search_item in enumerate(search_items, start=1):
        try:
            long_description = search_item["pagemap"]["metatags"][0]["og:description"]
        except KeyError:
            long_description = "N/A"
        # get the page title
        title = search_item.get("title")
        # page snippet
        snippet = search_item.get("snippet")
        # alternatively, you can get the HTML snippet (bolded keywords)
        html_snippet = search_item.get("htmlSnippet")
        # extract the page url
        link = search_item.get("link")
        links.append(link)
        # print the results
        print("="*10, f"Result #{i+start-1}", "="*10)
        print("Title:", title)
        print("Description:", snippet)
        print("Long description:", long_description)
        print("URL:", link, "\n")
    return links

# %%
def scrape_results(links):
    import openai
    from bs4 import BeautifulSoup
    with open("openai_api_key.txt", "r") as f:
        openai.api_key = f.read().strip()

    # Cycle through the urls to get the summarised answer
    answer = []
    num_results = 3

    for x in range(num_results):
        # Get the page content
        html = requests.get(links[x]).text

        # Extract the page title and text
        soup = BeautifulSoup(html, "html.parser")
        title = soup.title.string
        text = "\n".join([p.text for p in soup.find_all("p")])

        # Set up the GPT-3 API request
        request = f"Please summarize the following article:\nTitle: {title}\n\n{text[:4000]}"
        model = "text-davinci-003"
        params = {
            "prompt": request,
            "temperature": 0.5,
            "max_tokens": 100,
            "top_p": 1,
            "frequency_penalty": 0,
            "presence_penalty": 0
        }

        # Call the GPT-3 API and print the response
        response = openai.Completion.create(engine=model, **params)
        summary = response.choices[0].text.strip()
        answer.append(summary)
    return answer

# %%
# Clean the output
# Define function to clean text using GPT-3 API
def clean_text(t):    
    # Define parameters for GPT-3 API
    max_tokens = 2000
    temperature = 0.7
    stop = "\n\n"
    # Split text into smaller chunks and process each chunk separately
    chunk_size = 2000
    chunks = [t[i:i+chunk_size] for i in range(0, len(t), chunk_size)]
    cleaned_chunks = []
    for chunk in chunks:
        # Generate cleaned text using GPT-3 API
        # Define prompt for GPT-3 API
        prompt = (f"Please clean up the following text:\n\n{chunk}\n\n"
              "The cleaned text is:")
        print(prompt)
        response = openai.ChatCompletion.create(
                model = "gpt-3.5-turbo",
                messages = [
                    #{"role": "system", "content" : "You are able to perfectly clean and replicate text"},
                    {"role": "user", "content": prompt}]
            )
        print(response)
        cleaned_chunk = response['choices'][0]['message']['content']
        print(cleaned_chunk)
        cleaned_chunks.append(cleaned_chunk)

    # Join cleaned chunks into a single string and return it
    cleaned_text = "".join(cleaned_chunks)
    return cleaned_text.strip()

# %%
# Ask the questions
q1, q2 = ask_gpt()
query_clean = clean_query(q1, q2)
query_clean = query_clean.replace('"', '')
query_clean = query_clean.replace("'", '')
google_links = iterate_google(query_clean)
text_scraped = scrape_results(google_links)
# Convert to a string
text_string = ' '.join(text_scraped)
cleaned_text = clean_text(text_string)
print(cleaned_text)
# Out:
# 1. Homer
# 2. Iliad
# 3. Themes
# 4. New Yorker
# AIzaSyASjpYvuBFNcDmfNVIsLlT0_LK_aB7vaV0
# 672d1d4528bca4a1a
# Page number isn't specified, defaulting to 1
# What are the major themes of Homers Iliad?
# https://www.googleapis.com/customsearch/v1?cx=672d1d4528bca4a1a&key=AIzaSyASjpYvuBFNcDmfNVIsLlT0_LK_aB7vaV0&q=What are the major themes of Homers Iliad?&start=1
# Status code: 200
# Response content: {
#   "kind": "customsearch#search",
#   "url": {
#     "type": "application/json",
#     "template": "https://www.googleapis.com/customsearch/v1?q={searchTerms}&num={count?}&start={startIndex?}&lr={language?}&safe={safe?}&cx={cx?}&sort={sort?}&filter={filter?}&gl={gl?}&cr={cr?}&googlehost={googleHost?}&c2coff={disableCnTwTranslation?}&hq={hq?}&hl={hl?}&siteSearch={siteSearch?}&siteSearchFilter={siteSearchFilter?}&exactTerms={exactTerms?}&excludeTerms={excludeTerms?}&linkSite={linkSite?}&orTerms={orTerms?}&relatedSite={relatedSite?}&dateRestrict={dateRestrict?}&lowRange={lowRange?}&highRange={highRange?}&searchType={searchType}&fileType={fileType?}&rights={rights?}&imgSize={imgSize?}&imgType={imgType?}&imgColorType={imgColorType?}&imgDominantColor={imgDominantColor?}&alt=json"
#   },
#   "queries": {
#     "request": [
#       {
#         "title": "Google Custom Search - What are the major themes of Homers Iliad?",
#         "totalResults": "2110000",
#         "searchTerms": "What are the major themes of Homers Iliad?",
#         "count": 10,
#         "startIndex": 1,
#         "inputEncoding": "utf8",
#         "outputEncoding": "utf8",
#         "safe": "off",
#         "cx": "672d1d4528bca4a1a"
#       }
#     ],
#     "nextPage": [
#       {
#         "title": "Google Custom Search - What are the major themes of Homers Iliad?",
#         "totalResults": "2110000",
#         "searchTerms": "What are the major themes of Homers Iliad?",
#         "count": 10,
#         "startIndex": 11,
#         "inputEncoding": "utf8",
#         "outputEncoding": "utf8",
#         "safe": "off",
#         "cx": "672d1d4528bca4a1a"
#       }
#     ]
#   },
#   "context": {
#     "title": "SLC_test3"
#   },
#   "searchInformation": {
#     "searchTime": 0.434466,
#     "formattedSearchTime": "0.43",
#     "totalResults": "2110000",
#     "formattedTotalResults": "2,110,000"
#   },
#   "spelling": {
#     "correctedQuery": "What are the major themes of Homer's Iliad?",
#     "htmlCorrectedQuery": "What are the major themes of \u003cb\u003e\u003ci\u003eHomer&#39;s\u003c/i\u003e\u003c/b\u003e Iliad?"
#   },
#   "items": [
#     {
#       "kind": "customsearch#result",
#       "title": "The Iliad: Themes | SparkNotes",
#       "htmlTitle": "The \u003cb\u003eIliad\u003c/b\u003e: \u003cb\u003eThemes\u003c/b\u003e | SparkNotes",
#       "link": "https://www.sparknotes.com/lit/iliad/themes/",
#       "displayLink": "www.sparknotes.com",
#       "snippet": "The text clearly admires the reciprocal bonds of deference and obligation that bind Homeric families together, but it respects much more highly the pursuit of ...",
#       "htmlSnippet": "The text clearly admires the reciprocal bonds of deference and obligation that bind \u003cb\u003eHomeric\u003c/b\u003e families together, but it respects much more highly the pursuit of&nbsp;...",
#       "cacheId": "EOsZrLEhLKoJ",
#       "formattedUrl": "https://www.sparknotes.com/lit/iliad/themes/",
#       "htmlFormattedUrl": "https://www.sparknotes.com/lit/\u003cb\u003eiliad\u003c/b\u003e/\u003cb\u003ethemes\u003c/b\u003e/",
#       "pagemap": {
#         "cse_thumbnail": [
#           {
#             "src": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRGrAkxUG79dl6Yaxl265iz8UpGoL8t9atucDby8MlJaK3dt-kacHMyUrIc",
#             "width": "310",
#             "height": "163"
#           }
#         ],
#         "metatags": [
#           {
#             "og:image": "https://img.sparknotes.com/sparknotes_new-1200x630.jpg",
#             "theme-color": "#007ACD",
#             "twitter:card": "summary",
#             "og:site_name": "SparkNotes",
#             "twitter:site": "@SparkNotes",
#             "viewport": "width=device-width, initial-scale=1",
#             "og:title": "The Iliad: Themes | SparkNotes",
#             "og:url": "https://www.sparknotes.com/lit/iliad/themes/",
#             "og:description": "A summary of Themes in Homer's The Iliad."
#           }
#         ],
#         "cse_image": [
#           {
#             "src": "https://img.sparknotes.com/sparknotes_new-1200x630.jpg"
#           }
#         ]
#       }
#     },
#     {
#       "kind": "customsearch#result",
#       "title": "Themes in The Iliad - Video & Lesson Transcript | Study.com",
#       "htmlTitle": "\u003cb\u003eThemes in\u003c/b\u003e The \u003cb\u003eIliad\u003c/b\u003e - Video &amp; Lesson Transcript | Study.com",
#       "link": "https://study.com/academy/lesson/themes-in-the-iliad.html",
#       "displayLink": "study.com",
#       "snippet": "Dec 22, 2021 ... Greek literature and mythology rely heavily on the theme of fate and free will. Homer's The Iliad is no exception. The fates of Achilles and ...",
#       "htmlSnippet": "Dec 22, 2021 \u003cb\u003e...\u003c/b\u003e Greek literature and mythology rely heavily on the \u003cb\u003etheme\u003c/b\u003e of fate and free will. \u003cb\u003eHomer&#39;s\u003c/b\u003e The \u003cb\u003eIliad\u003c/b\u003e is no exception. The fates of Achilles and&nbsp;...",
#       "cacheId": "rw94RKKQSo8J",
#       "formattedUrl": "https://study.com/academy/lesson/themes-in-the-iliad.html",
#       "htmlFormattedUrl": "https://study.com/academy/lesson/\u003cb\u003ethemes-in\u003c/b\u003e-the-\u003cb\u003eiliad\u003c/b\u003e.html",
#       "pagemap": {
#         "cse_thumbnail": [
#           {
#             "src": "https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcS7zC_c6l31EVxvYgkOAbENgDh7tcumatPFVtP_G0cTgRG-Y15IIB4gQQg",
#             "width": "300",
#             "height": "168"
#           }
#         ],
#         "metatags": [
#           {
#             "og:image": "https://study.com/cimages/videopreview/jc9zlukk9c.jpg",
#             "og:type": "article",
#             "og:site_name": "study.com",
#             "impressionguid": "A3A9982A-1557-64BE-F535-662EFE7F86A2",
#             "viewport": "width=device-width, initial-scale=1",
#             "og:title": "Themes in The Iliad - Video & Lesson Transcript | Study.com",
#             "og:image:type": "image/jpg",
#             "og:url": "https://study.com/academy/lesson/themes-in-the-iliad.html",
#             "og:description": "Explore some of the key themes in Homer's epic poem, 'The Iliad.' Discover how the themes of love and friendship guide the plot, explore questions...",
#             "requestguid": "00c31a89a28b97d0b17c297b47ede776",
#             "google-signin-client_id": "326120504594-f9a12d1t4bguk0netbgc8ed0k1rttga1.apps.googleusercontent.com",
#             "sid": "202303-11ed-bd3a-f679bec5-b748-0e8a7f1215fd"
#           }
#         ],
#         "videoobject": [
#           {
#             "duration": "PT4M44S",
#             "contenturl": "https://embed-ssl.wistia.com/deliveries/5c266635d5efacb46d76b8c13576fe09b38f56e1/file.mp4",
#             "uploaddate": "2019-03-28",
#             "name": "Themes in The Iliad Video",
#             "description": "Explore some of the key themes in Homer's epic poem, 'The Iliad.' Discover how the themes of love and friendship guide the plot, explore questions of fate versus free will and discover the...",
#             "thumbnailurl": "https://study.com/cimages/videopreview/jc9zlukk9c.jpg"
#           }
#         ],
#         "cse_image": [
#           {
#             "src": "https://study.com/cimages/videopreview/jc9zlukk9c.jpg"
#           }
#         ]
#       }
#     },
#     {
#       "kind": "customsearch#result",
#       "title": "Themes in The Iliad",
#       "htmlTitle": "\u003cb\u003eThemes in\u003c/b\u003e The \u003cb\u003eIliad\u003c/b\u003e",
#       "link": "https://www.cliffsnotes.com/literature/i/the-iliad/critical-essays/themes-in-the-iliad",
#       "displayLink": "www.cliffsnotes.com",
#       "snippet": "The main theme of the Iliad is stated in the first line, as Homer asks the Muse to sing of the \"wrath of Achilles.\" This wrath, all its permutations, ...",
#       "htmlSnippet": "The \u003cb\u003emain theme\u003c/b\u003e of the \u003cb\u003eIliad\u003c/b\u003e is stated in the first line, as \u003cb\u003eHomer\u003c/b\u003e asks the Muse to sing of the &quot;wrath of Achilles.&quot; This wrath, all its permutations,&nbsp;...",
#       "cacheId": "6zPBVYDtleAJ",
#       "formattedUrl": "https://www.cliffsnotes.com/literature/i/the-iliad/critical.../themes-in-the-iliad",
#       "htmlFormattedUrl": "https://www.cliffsnotes.com/literature/i/the-\u003cb\u003eiliad\u003c/b\u003e/critical.../\u003cb\u003ethemes-in\u003c/b\u003e-the-\u003cb\u003eiliad\u003c/b\u003e",
#       "pagemap": {
#         "cse_thumbnail": [
#           {
#             "src": "https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcRHDPAtrPjkWSmvwULqu6pYxlIf-NbhzCbVaBya1GmdSSyJufLQzlpGcMZf",
#             "width": "265",
#             "height": "190"
#           }
#         ],
#         "metatags": [
#           {
#             "viewport": "width=device-width, initial-scale=1.0"
#           }
#         ],
#         "cse_image": [
#           {
#             "src": "https://www.cliffsnotes.com/packs/media/images/sign-up/Sell-Page-PDF_Desktop-Tablet-Blurred-30d7c1922b9afb6a90d96a27dddfc976.png"
#           }
#         ]
#       }
#     },
#     {
#       "kind": "customsearch#result",
#       "title": "Themes in the Iliad by Homer | Overview, Analysis & Importance ...",
#       "htmlTitle": "\u003cb\u003eThemes in\u003c/b\u003e the \u003cb\u003eIliad\u003c/b\u003e by \u003cb\u003eHomer\u003c/b\u003e | Overview, Analysis &amp; Importance ...",
#       "link": "https://study.com/learn/lesson/themes-iliad-overview-analysis-importance.html",
#       "displayLink": "study.com",
#       "snippet": "Jun 23, 2022 ... The major themes in Homer's epic poem The Iliad are revenge, war and mortality, love and friendship, fate v free will and honor. The theme of ...",
#       "htmlSnippet": "Jun 23, 2022 \u003cb\u003e...\u003c/b\u003e The \u003cb\u003emajor themes in Homer&#39;s\u003c/b\u003e epic poem The \u003cb\u003eIliad\u003c/b\u003e are revenge, war and mortality, love and friendship, fate v free will and honor. The \u003cb\u003etheme\u003c/b\u003e of&nbsp;...",
#       "cacheId": "cTXv8wwmNhIJ",
#       "formattedUrl": "https://study.com/learn/.../themes-iliad-overview-analysis-importance.html",
#       "htmlFormattedUrl": "https://study.com/learn/.../\u003cb\u003ethemes\u003c/b\u003e-\u003cb\u003eiliad\u003c/b\u003e-overview-analysis-importance.html",
#       "pagemap": {
#         "cse_thumbnail": [
#           {
#             "src": "https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcS7zC_c6l31EVxvYgkOAbENgDh7tcumatPFVtP_G0cTgRG-Y15IIB4gQQg",
#             "width": "300",
#             "height": "168"
#           }
#         ],
#         "question": [
#           {
#             "name": "What are the major themes in The Iliad?"
#           },
#           {
#             "name": "What is the moral message of The Iliad?"
#           }
#         ],
#         "answer": [
#           {
#             "text": "The major themes in Homer's epic poem The Iliad are revenge, war and mortality, love and friendship, fate v free will and honor. The theme of revenge drives the plot from the beginning of the..."
#           },
#           {
#             "text": "While we are living, we have an opportunity to write our own stories that will be told long after we we die. Homer illuminates this idea through the theme of mortality. In this time period..."
#           }
#         ],
#         "metatags": [
#           {
#             "og:image": "https://study.com/cimages/videopreview/jc9zlukk9c.jpg",
#             "og:type": "article",
#             "og:site_name": "study.com",
#             "impressionguid": "A3A9982A-1557-64BE-F535-662EFE7F86A2",
#             "viewport": "width=device-width, initial-scale=1",
#             "og:title": "Themes in the Iliad by Homer | Overview, Analysis & Importance - Video & Lesson Transcript | Study.com",
#             "og:image:type": "image/jpg",
#             "og:url": "https://study.com/learn/lesson/themes-iliad-overview-analysis-importance.html",
#             "og:description": "Explore the themes in The Iliad. Study the importance of the themes in Homer's epic, and examine the depiction of war, love and friendship,...",
#             "requestguid": "8c67a09f27e7fbd64b5d04c7dc231f26",
#             "google-signin-client_id": "326120504594-f9a12d1t4bguk0netbgc8ed0k1rttga1.apps.googleusercontent.com",
#             "sid": "202303-11ed-b97e-01b8cf90-93cd-0efe2c470605"
#           }
#         ],
#         "videoobject": [
#           {
#             "duration": "PT4M44S",
#             "contenturl": "https://embed-ssl.wistia.com/deliveries/5c266635d5efacb46d76b8c13576fe09b38f56e1/file.mp4",
#             "uploaddate": "2019-03-28",
#             "name": "Themes in the Iliad by Homer | Overview, Analysis & Importance Video",
#             "description": "Explore the themes in The Iliad. Study the importance of the themes in Homer's epic, and examine the depiction of war, love and friendship, revenge, and many more.",
#             "thumbnailurl": "https://study.com/cimages/videopreview/jc9zlukk9c.jpg"
#           }
#         ],
#         "cse_image": [
#           {
#             "src": "https://study.com/cimages/videopreview/jc9zlukk9c.jpg"
#           }
#         ]
#       }
#     },
#     {
#       "kind": "customsearch#result",
#       "title": "The Iliad Themes | LitCharts",
#       "htmlTitle": "The \u003cb\u003eIliad Themes\u003c/b\u003e | LitCharts",
#       "link": "https://www.litcharts.com/lit/the-iliad/themes",
#       "displayLink": "www.litcharts.com",
#       "snippet": "Honor and Glory. One of the central ideas of the Iliad is the honor that soldiers earn in combat. · The Gods. The gods in Homer often take an active interest in ...",
#       "htmlSnippet": "Honor and Glory. One of the \u003cb\u003ecentral\u003c/b\u003e ideas of the \u003cb\u003eIliad\u003c/b\u003e is the honor that soldiers earn in combat. &middot; The Gods. The gods in \u003cb\u003eHomer\u003c/b\u003e often take an active interest in&nbsp;...",
#       "cacheId": "urFewBUmZtgJ",
#       "formattedUrl": "https://www.litcharts.com/lit/the-iliad/themes",
#       "htmlFormattedUrl": "https://www.litcharts.com/lit/the-\u003cb\u003eiliad\u003c/b\u003e/\u003cb\u003ethemes\u003c/b\u003e",
#       "pagemap": {
#         "cse_thumbnail": [
#           {
#             "src": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS5aZHNXz-f-oYo1lE03LwxLt_Unp3Hk16j9OZn8K0qBG7tZ7ScA4HfFg",
#             "width": "544",
#             "height": "93"
#           }
#         ],
#         "metatags": [
#           {
#             "msapplication-config": "none",
#             "og:image": "https://cdn.litcharts.com/logo-and-wordmark.png",
#             "og:type": "article",
#             "twitter:card": "The Iliad Themes | LitCharts",
#             "og:site_name": "LitCharts",
#             "msvalidate.01": "E874522C1C89460399152B87720D9D37",
#             "og:title": "LitCharts",
#             "csrf-param": "authenticity_token",
#             "og:description": "The Iliad Themes | LitCharts",
#             "twitter:creator": "@litcharts",
#             "twitter:site": "@litcharts",
#             "viewport": "width=device-width, initial-scale=1.0",
#             "csrf-token": "Ii4pprj+t7ZF7nPUMKgugj5MI4Ri63SreKp8O9TqczNYC3VYyg3IHf3+sRGXhAiLEQLZGaHC1JhAKrXaYK61aA=="
#           }
#         ],
#         "cse_image": [
#           {
#             "src": "https://cdn.litcharts.com/logo-and-wordmark.png"
#           }
#         ]
#       }
#     },
#     {
#       "kind": "customsearch#result",
#       "title": "Six Major Iliad Themes That Express Universal Truths",
#       "htmlTitle": "Six \u003cb\u003eMajor Iliad Themes\u003c/b\u003e That Express Universal Truths",
#       "link": "https://ancient-literature.com/iliad-themes/",
#       "displayLink": "ancient-literature.com",
#       "snippet": "Iliad Themes ; Glory and Honor, Warriors aimed for glory and honor on the battlefield. ; The intervention of the Gods, The deities interfered in human affairs.",
#       "htmlSnippet": "\u003cb\u003eIliad Themes\u003c/b\u003e ; Glory and Honor, Warriors aimed for glory and honor on the battlefield. ; The intervention of the Gods, The deities interfered in human affairs.",
#       "cacheId": "5i1jvMMTsW4J",
#       "formattedUrl": "https://ancient-literature.com/iliad-themes/",
#       "htmlFormattedUrl": "https://ancient-literature.com/\u003cb\u003eiliad\u003c/b\u003e-\u003cb\u003ethemes\u003c/b\u003e/",
#       "pagemap": {
#         "cse_thumbnail": [
#           {
#             "src": "https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcRrWXfXj3M7fxnFS34Rs2VXpRq1w-hHejX1Id-rn_0VzZSqSU_iMbfGi-qO",
#             "width": "275",
#             "height": "183"
#           }
#         ],
#         "metatags": [
#           {
#             "og:image": "https://ancient-literature.com/wp-content/uploads/2022/05/Iliad-Themes.jpg",
#             "og:type": "article",
#             "article:section": "Blog",
#             "og:image:width": "1024",
#             "og:image:alt": "Iliad themes",
#             "article:published_time": "2022-06-02T10:33:08+00:00",
#             "twitter:card": "summary_large_image",
#             "twitter:title": "Six Unique Iliad Themes That Are Universally Relatable",
#             "og:site_name": "Ancient Literature",
#             "og:title": "Six Unique Iliad Themes That Are Universally Relatable",
#             "og:image:height": "682",
#             "og:image:type": "image/jpeg",
#             "og:updated_time": "2022-06-16T14:15:35+00:00",
#             "msapplication-tileimage": "https://ancient-literature.com/wp-content/uploads/2020/12/cropped-icone-Ancient-270x270.jpg",
#             "og:description": "The Iliad themes are central ideas that Homer explores in his epic poem. Read on to discover six of these themes and how they are conveyed in the Iliad.",
#             "og:image:secure_url": "https://ancient-literature.com/wp-content/uploads/2022/05/Iliad-Themes.jpg",
#             "twitter:image": "https://ancient-literature.com/wp-content/uploads/2022/05/Iliad-Themes.jpg",
#             "article:modified_time": "2022-06-16T14:15:35+00:00",
#             "viewport": "width=device-width, initial-scale=1, minimum-scale=1",
#             "twitter:description": "The Iliad themes are central ideas that Homer explores in his epic poem. Read on to discover six of these themes and how they are conveyed in the Iliad.",
#             "og:locale": "en_US",
#             "og:url": "https://ancient-literature.com/iliad-themes/"
#           }
#         ],
#         "cse_image": [
#           {
#             "src": "https://ancient-literature.com/wp-content/uploads/2022/05/Iliad-Themes.jpg"
#           }
#         ],
#         "hatomfeed": [
#           {}
#         ]
#       }
#     },
#     {
#       "kind": "customsearch#result",
#       "title": "The Iliad Themes – Meaning and Main Ideas - Writing Explained",
#       "htmlTitle": "The \u003cb\u003eIliad Themes\u003c/b\u003e – Meaning and \u003cb\u003eMain\u003c/b\u003e Ideas - Writing Explained",
#       "link": "https://writingexplained.org/literature/iliad/themes",
#       "displayLink": "writingexplained.org",
#       "snippet": "The Iliad Themes · The Glory of War Heroes · Military Victories Values Above Personal Life · The Fleeting Nature of Human Existence ...",
#       "htmlSnippet": "The \u003cb\u003eIliad Themes\u003c/b\u003e &middot; The Glory of War Heroes &middot; Military Victories Values Above Personal Life &middot; The Fleeting Nature of Human Existence&nbsp;...",
#       "cacheId": "xoFjdJgtCfEJ",
#       "formattedUrl": "https://writingexplained.org/literature/iliad/themes",
#       "htmlFormattedUrl": "https://writingexplained.org/literature/\u003cb\u003eiliad\u003c/b\u003e/\u003cb\u003ethemes\u003c/b\u003e",
#       "pagemap": {
#         "cse_thumbnail": [
#           {
#             "src": "https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcRjTAhlX4WHr7CuE5_Y2gO99tkOT5hFyxcFjf34ms9I2zl5zTqxU4wtcm2w",
#             "width": "328",
#             "height": "153"
#           }
#         ],
#         "metatags": [
#           {
#             "og:image": "https://writingexplained.org/wp-content/uploads/themes-in-the-iliad.png",
#             "og:type": "article",
#             "og:site_name": "Writing Explained",
#             "viewport": "width=device-width, initial-scale=1",
#             "og:title": "The Iliad Themes – Meaning and Main Ideas - Writing Explained",
#             "og:locale": "en_US",
#             "twitter:label1": "Est. reading time",
#             "og:url": "https://writingexplained.org/literature/iliad/themes",
#             "og:description": "Summary of themes and meaning in Homer’s The Iliad. What is the main theme of the Iliad? Iliad theme analysis",
#             "article:publisher": "https://www.facebook.com/WritingExplained",
#             "twitter:data1": "4 minutes"
#           }
#         ],
#         "creativework": [
#           {
#             "text": "Main Themes in Homer’s Iliad The Iliad is set in the tenth and final year of the Trojan war. It’s the Bronze Age, so around the 13th century B.C. Much of the action takes place on the gruesome...",
#             "headline": "The Iliad Themes – Meaning and Main Ideas"
#           }
#         ],
#         "cse_image": [
#           {
#             "src": "https://writingexplained.org/wp-content/uploads/themes-in-the-iliad.png"
#           }
#         ]
#       }
#     },
#     {
#       "kind": "customsearch#result",
#       "title": "Themes in The Iliad with examples and analysis - Literary Devices",
#       "htmlTitle": "\u003cb\u003eThemes in\u003c/b\u003e The \u003cb\u003eIliad\u003c/b\u003e with examples and analysis - Literary Devices",
#       "link": "https://literarydevices.net/the-iliad-themes/",
#       "displayLink": "literarydevices.net",
#       "snippet": "A war testing every character, their humanity, and finer feelings are in this epic. Although Achilles proves himself a hero, he seeks revenge and glory without ...",
#       "htmlSnippet": "A war testing every character, their humanity, and finer feelings are in this epic. Although Achilles proves himself a hero, he seeks revenge and glory without&nbsp;...",
#       "cacheId": "xoMIQ1afO7cJ",
#       "formattedUrl": "https://literarydevices.net/the-iliad-themes/",
#       "htmlFormattedUrl": "https://literarydevices.net/the-\u003cb\u003eiliad\u003c/b\u003e-\u003cb\u003ethemes\u003c/b\u003e/",
#       "pagemap": {
#         "metatags": [
#           {
#             "og:type": "article",
#             "article:section": "Literary Analysis",
#             "article:published_time": "2019-12-23T17:12:16-04:00",
#             "twitter:card": "summary_large_image",
#             "twitter:title": "Themes in The Iliad with examples and analysis - Literary Devices",
#             "og:site_name": "Literary Devices",
#             "og:title": "Themes in The Iliad with examples and analysis - Literary Devices",
#             "og:updated_time": "2019-12-23T17:13:31-04:00",
#             "og:description": "Great examples and literary analysis of the use of themes in Homer's The Iliad.",
#             "article:tag": "homer",
#             "article:modified_time": "2019-12-23T17:13:31-04:00",
#             "viewport": "width=device-width,initial-scale=1",
#             "twitter:description": "Great examples and literary analysis of the use of themes in Homer's The Iliad.",
#             "og:locale": "en_US",
#             "og:url": "https://literarydevices.net/the-iliad-themes/"
#           }
#         ]
#       }
#     },
#     {
#       "kind": "customsearch#result",
#       "title": "Homer's Iliad Explained - Characters, Symbols, & Themes - Writing ...",
#       "htmlTitle": "\u003cb\u003eHomer&#39;s Iliad\u003c/b\u003e Explained - Characters, Symbols, &amp; \u003cb\u003eThemes\u003c/b\u003e - Writing ...",
#       "link": "https://writingexplained.org/literature/iliad",
#       "displayLink": "writingexplained.org",
#       "snippet": "Homer's Iliad Explained – Characters, Symbols, & Themes · Homer's Iliad Introduction · Summary · Character Descriptions · Major Themes · Major Symbols.",
#       "htmlSnippet": "\u003cb\u003eHomer&#39;s Iliad\u003c/b\u003e Explained – Characters, Symbols, &amp; \u003cb\u003eThemes\u003c/b\u003e &middot; \u003cb\u003eHomer&#39;s Iliad\u003c/b\u003e Introduction &middot; Summary &middot; Character Descriptions &middot; \u003cb\u003eMajor Themes\u003c/b\u003e &middot; \u003cb\u003eMajor\u003c/b\u003e Symbols.",
#       "cacheId": "5Y3RVYv0PwAJ",
#       "formattedUrl": "https://writingexplained.org/literature/iliad",
#       "htmlFormattedUrl": "https://writingexplained.org/literature/\u003cb\u003eiliad\u003c/b\u003e",
#       "pagemap": {
#         "cse_thumbnail": [
#           {
#             "src": "https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcS76pRQBkCkiCiEtT7ho6cFvspUUjZTplnj7xHLhroy6DeR8AvHPJ2vMpFm",
#             "width": "328",
#             "height": "153"
#           }
#         ],
#         "metatags": [
#           {
#             "og:image": "https://writingexplained.org/wp-content/uploads/iliad-summary.png",
#             "og:type": "article",
#             "og:site_name": "Writing Explained",
#             "article:modified_time": "2021-05-05T20:33:01+00:00",
#             "viewport": "width=device-width, initial-scale=1",
#             "og:title": "Homer's Iliad Explained - Characters, Symbols, & Themes - Writing Explained",
#             "og:locale": "en_US",
#             "twitter:label1": "Est. reading time",
#             "og:url": "https://writingexplained.org/literature/iliad",
#             "og:description": "Homer’s Iliad Introduction Summary Read a complete overview of Homer’s Iliad along with an outline of its literary elements. Book Summary \u003e\u003e Major Literary Elements \u003e\u003e Literary Significance \u003e\u003e Character Descriptions Who are the characters in Iliad? Character Analysis \u003e\u003e Major Themes What are the major themes in Iliad? Major Themes \u003e\u003e Major Symbols What ... Read more",
#             "article:publisher": "https://www.facebook.com/WritingExplained",
#             "twitter:data1": "1 minute"
#           }
#         ],
#         "creativework": [
#           {
#             "text": "Homer’s Iliad Introduction Summary Read a complete overview of Homer’s Iliad along with an outline of its literary elements. Book Summary \u003e\u003e Major Literary Elements \u003e\u003e Literary Significance...",
#             "headline": "Homer’s Iliad Explained – Characters, Symbols, & Themes"
#           }
#         ],
#         "cse_image": [
#           {
#             "src": "https://writingexplained.org/wp-content/uploads/iliad-summary.png"
#           }
#         ]
#       }
#     },
#     {
#       "kind": "customsearch#result",
#       "title": "Homer's \"Iliad\" and \"Odyssey\": Main Themes - 347 Words | Essay ...",
#       "htmlTitle": "\u003cb\u003eHomer&#39;s\u003c/b\u003e &quot;\u003cb\u003eIliad\u003c/b\u003e&quot; and &quot;Odyssey&quot;: \u003cb\u003eMain Themes\u003c/b\u003e - 347 Words | Essay ...",
#       "link": "https://ivypanda.com/essays/homers-iliad-and-odyssey-main-themes/",
#       "displayLink": "ivypanda.com",
#       "snippet": "Oct 8, 2022 ... Homer's “Iliad” and “Odyssey”: Main Themes Essay ... The main topics that have currently dominated the world are conflicts and politics.",
#       "htmlSnippet": "Oct 8, 2022 \u003cb\u003e...\u003c/b\u003e \u003cb\u003eHomer&#39;s\u003c/b\u003e “\u003cb\u003eIliad\u003c/b\u003e” and “Odyssey”: \u003cb\u003eMain Themes\u003c/b\u003e Essay ... The \u003cb\u003emain\u003c/b\u003e topics that have currently dominated the world are conflicts and politics.",
#       "cacheId": "34K-CnPr86oJ",
#       "formattedUrl": "https://ivypanda.com/essays/homers-iliad-and-odyssey-main-themes/",
#       "htmlFormattedUrl": "https://ivypanda.com/essays/\u003cb\u003ehomers\u003c/b\u003e-\u003cb\u003eiliad\u003c/b\u003e-and-odyssey-\u003cb\u003emain\u003c/b\u003e-\u003cb\u003ethemes\u003c/b\u003e/",
#       "pagemap": {
#         "cse_thumbnail": [
#           {
#             "src": "https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcRE4MRYT-G70iou_kthIwBNfLHJObVGizZEb1lAo094B1zMUh-I6L08alg",
#             "width": "310",
#             "height": "162"
#           }
#         ],
#         "metatags": [
#           {
#             "og:image": "https://ivypanda.com/outer/img/jpg/ogimage.jpg",
#             "theme-color": "#00988a",
#             "og:type": "website",
#             "og:image:width": "768",
#             "og:image:alt": "Homer's \"Iliad\" and \"Odyssey\": Main Themes - 347 Words | Essay Example",
#             "twitter:card": "summary",
#             "twitter:title": "Homer's \"Iliad\" and \"Odyssey\": Main Themes - 347 Words | Essay Example",
#             "og:site_name": "Free Essays",
#             "twitter:url": "https://ivypanda.com/essays/homers-iliad-and-odyssey-main-themes/",
#             "og:title": "Homer's \"Iliad\" and \"Odyssey\": Main Themes - 347 Words | Essay Example",
#             "og:image:height": "402",
#             "og:image:type": "image/jpeg",
#             "og:description": "In the “Iliad” the story focuses on the conflict between different groups with distinct interests. “Odyssey” mainly focuses on politics and leadership.",
#             "twitter:image": "https://ivypanda.com/outer/img/jpg/ogimage.jpg",
#             "viewport": "width=device-width, initial-scale=1, viewport-fit=cover",
#             "twitter:description": "In the “Iliad” the story focuses on the conflict between different groups with distinct interests. “Odyssey” mainly focuses on politics and leadership.",
#             "position": "3",
#             "og:url": "https://ivypanda.com/essays/homers-iliad-and-odyssey-main-themes/"
#           }
#         ],
#         "creativework": [
#           {
#             "\"timerequired\"": "P0DT0H2M0S",
#             "text": "Homer’s Iliad and Odyssey remain powerful even today because they relate to the current issues. The main topics that have currently dominated the world are conflicts and politics. In the..."
#           },
#           {
#             "name": "The Nordic origins of the Iliad and Odyssey: An up-to-date survey of the theory.",
#             "url": "The Nordic origins of the Iliad and Odyssey: An up-to-date survey of the theory."
#           }
#         ],
#         "cse_image": [
#           {
#             "src": "https://ivypanda.com/outer/img/jpg/ogimage.jpg"
#           }
#         ]
#       }
#     }
#   ]
# }
#
# [{'kind': 'customsearch#result', 'title': 'The Iliad: Themes | SparkNotes', 'htmlTitle': 'The <b>Iliad</b>: <b>Themes</b> | SparkNotes', 'link': 'https://www.sparknotes.com/lit/iliad/themes/', 'displayLink': 'www.sparknotes.com', 'snippet': 'The text clearly admires the reciprocal bonds of deference and obligation that bind Homeric families together, but it respects much more highly the pursuit of\xa0...', 'htmlSnippet': 'The text clearly admires the reciprocal bonds of deference and obligation that bind <b>Homeric</b> families together, but it respects much more highly the pursuit of&nbsp;...', 'cacheId': 'EOsZrLEhLKoJ', 'formattedUrl': 'https://www.sparknotes.com/lit/iliad/themes/', 'htmlFormattedUrl': 'https://www.sparknotes.com/lit/<b>iliad</b>/<b>themes</b>/', 'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRGrAkxUG79dl6Yaxl265iz8UpGoL8t9atucDby8MlJaK3dt-kacHMyUrIc', 'width': '310', 'height': '163'}], 'metatags': [{'og:image': 'https://img.sparknotes.com/sparknotes_new-1200x630.jpg', 'theme-color': '#007ACD', 'twitter:card': 'summary', 'og:site_name': 'SparkNotes', 'twitter:site': '@SparkNotes', 'viewport': 'width=device-width, initial-scale=1', 'og:title': 'The Iliad: Themes | SparkNotes', 'og:url': 'https://www.sparknotes.com/lit/iliad/themes/', 'og:description': "A summary of Themes in Homer's The Iliad."}], 'cse_image': [{'src': 'https://img.sparknotes.com/sparknotes_new-1200x630.jpg'}]}}, {'kind': 'customsearch#result', 'title': 'Themes in The Iliad - Video & Lesson Transcript | Study.com', 'htmlTitle': '<b>Themes in</b> The <b>Iliad</b> - Video &amp; Lesson Transcript | Study.com', 'link': 'https://study.com/academy/lesson/themes-in-the-iliad.html', 'displayLink': 'study.com', 'snippet': "Dec 22, 2021 ... Greek literature and mythology rely heavily on the theme of fate and free will. Homer's The Iliad is no exception. The fates of Achilles and\xa0...", 'htmlSnippet': 'Dec 22, 2021 <b>...</b> Greek literature and mythology rely heavily on the <b>theme</b> of fate and free will. <b>Homer&#39;s</b> The <b>Iliad</b> is no exception. The fates of Achilles and&nbsp;...', 'cacheId': 'rw94RKKQSo8J', 'formattedUrl': 'https://study.com/academy/lesson/themes-in-the-iliad.html', 'htmlFormattedUrl': 'https://study.com/academy/lesson/<b>themes-in</b>-the-<b>iliad</b>.html', 'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcS7zC_c6l31EVxvYgkOAbENgDh7tcumatPFVtP_G0cTgRG-Y15IIB4gQQg', 'width': '300', 'height': '168'}], 'metatags': [{'og:image': 'https://study.com/cimages/videopreview/jc9zlukk9c.jpg', 'og:type': 'article', 'og:site_name': 'study.com', 'impressionguid': 'A3A9982A-1557-64BE-F535-662EFE7F86A2', 'viewport': 'width=device-width, initial-scale=1', 'og:title': 'Themes in The Iliad - Video & Lesson Transcript | Study.com', 'og:image:type': 'image/jpg', 'og:url': 'https://study.com/academy/lesson/themes-in-the-iliad.html', 'og:description': "Explore some of the key themes in Homer's epic poem, 'The Iliad.' Discover how the themes of love and friendship guide the plot, explore questions...", 'requestguid': '00c31a89a28b97d0b17c297b47ede776', 'google-signin-client_id': '326120504594-f9a12d1t4bguk0netbgc8ed0k1rttga1.apps.googleusercontent.com', 'sid': '202303-11ed-bd3a-f679bec5-b748-0e8a7f1215fd'}], 'videoobject': [{'duration': 'PT4M44S', 'contenturl': 'https://embed-ssl.wistia.com/deliveries/5c266635d5efacb46d76b8c13576fe09b38f56e1/file.mp4', 'uploaddate': '2019-03-28', 'name': 'Themes in The Iliad Video', 'description': "Explore some of the key themes in Homer's epic poem, 'The Iliad.' Discover how the themes of love and friendship guide the plot, explore questions of fate versus free will and discover the...", 'thumbnailurl': 'https://study.com/cimages/videopreview/jc9zlukk9c.jpg'}], 'cse_image': [{'src': 'https://study.com/cimages/videopreview/jc9zlukk9c.jpg'}]}}, {'kind': 'customsearch#result', 'title': 'Themes in The Iliad', 'htmlTitle' ...
# ========== Result #1 ==========
# Title: The Iliad: Themes | SparkNotes
# Description: The text clearly admires the reciprocal bonds of deference and obligation that bind Homeric families together, but it respects much more highly the pursuit of ...
# Long description: A summary of Themes in Homer's The Iliad.
# URL: https://www.sparknotes.com/lit/iliad/themes/
#
# ========== Result #2 ==========
# Title: Themes in The Iliad - Video & Lesson Transcript | Study.com
# Description: Dec 22, 2021 ... Greek literature and mythology rely heavily on the theme of fate and free will. Homer's The Iliad is no exception. The fates of Achilles and ...
# Long description: Explore some of the key themes in Homer's epic poem, 'The Iliad.' Discover how the themes of love and friendship guide the plot, explore questions...
# URL: https://study.com/academy/lesson/themes-in-the-iliad.html
#
# ========== Result #3 ==========
# Title: Themes in The Iliad
# Description: The main theme of the Iliad is stated in the first line, as Homer asks the Muse to sing of the "wrath of Achilles." This wrath, all its permutations, ...
# Long description: N/A
# URL: https://www.cliffsnotes.com/literature/i/the-iliad/critical-essays/themes-in-the-iliad
#
# ========== Result #4 ==========
# Title: Themes in the Iliad by Homer | Overview, Analysis & Importance ...
# Description: Jun 23, 2022 ... The major themes in Homer's epic poem The Iliad are revenge, war and mortality, love and friendship, fate v free will and honor. The theme of ...
# Long description: Explore the themes in The Iliad. Study the importance of the themes in Homer's epic, and examine the depiction of war, love and friendship,...
# URL: https://study.com/learn/lesson/themes-iliad-overview-analysis-importance.html
#
# ========== Result #5 ==========
# Title: The Iliad Themes | LitCharts
# Description: Honor and Glory. One of the central ideas of the Iliad is the honor that soldiers earn in combat. · The Gods. The gods in Homer often take an active interest in ...
# Long description: The Iliad Themes | LitCharts
# URL: https://www.litcharts.com/lit/the-iliad/themes
#
# ========== Result #6 ==========
# Title: Six Major Iliad Themes That Express Universal Truths
# Description: Iliad Themes ; Glory and Honor, Warriors aimed for glory and honor on the battlefield. ; The intervention of the Gods, The deities interfered in human affairs.
# Long description: The Iliad themes are central ideas that Homer explores in his epic poem. Read on to discover six of these themes and how they are conveyed in the Iliad.
# URL: https://ancient-literature.com/iliad-themes/
#
# ========== Result #7 ==========
# Title: The Iliad Themes – Meaning and Main Ideas - Writing Explained
# Description: The Iliad Themes · The Glory of War Heroes · Military Victories Values Above Personal Life · The Fleeting Nature of Human Existence ...
# Long description: Summary of themes and meaning in Homer’s The Iliad. What is the main theme of the Iliad? Iliad theme analysis
# URL: https://writingexplained.org/literature/iliad/themes
#
# ========== Result #8 ==========
# Title: Themes in The Iliad with examples and analysis - Literary Devices
# Description: A war testing every character, their humanity, and finer feelings are in this epic. Although Achilles proves himself a hero, he seeks revenge and glory without ...
# Long description: Great examples and literary analysis of the use of themes in Homer's The Iliad.
# URL: https://literarydevices.net/the-iliad-themes/
#
# ========== Result #9 ==========
# Title: Homer's Iliad Explained - Characters, Symbols, & Themes - Writing ...
# Description: Homer's Iliad Explained – Characters, Symbols, & Themes · Homer's Iliad Introduction · Summary · Character Descriptions · Major Themes · Major Symbols.
# Long description: Homer’s Iliad Introduction Summary Read a complete overview of Homer’s Iliad along with an outline of its literary elements. Book Summary >> Major Literary Elements >> Literary Significance >> Character Descriptions Who are the characters in Iliad? Character Analysis >> Major Themes What are the major themes in Iliad? Major Themes >> Major Symbols What ... Read more
# URL: https://writingexplained.org/literature/iliad
#
# ========== Result #10 ==========
# Title: Homer's "Iliad" and "Odyssey": Main Themes - 347 Words | Essay ...
# Description: Oct 8, 2022 ... Homer's “Iliad” and “Odyssey”: Main Themes Essay ... The main topics that have currently dominated the world are conflicts and politics.
# Long description: In the “Iliad” the story focuses on the conflict between different groups with distinct interests. “Odyssey” mainly focuses on politics and leadership.
# URL: https://ivypanda.com/essays/homers-iliad-and-odyssey-main-themes/
#
# Please clean up the following text:
#
# y associated with war is the idea that characters are judged based on their courage and ability in battle. The poem also acknowledges the realities of war, such as death and destruction, but still holds up warfare as a respectable and even glorious way to settle disputes. Erich Maria Remarque's All Quiet on the Western Front provides a contrasting view on war and its effects. I hold out here and I lay siege to Troy,
# my journey home is gone, but my glory never dies.'
# Achilles chooses to stay and fight in the Trojan War despite the fact that it will mean his death. He chooses to stay in order to earn honor and glory, which will live on after his death.
# This article discusses the themes of love and friendship, fate and free will, and honor as they are explored in Homer's epic poem The Ili win numerous victories.
# Eventually, Achilles' anger leads to reconciliation. Achilles' anger is assuaged by the death of Patroklos and the return of his arms and his honor. Achilles rejoins the war, reconciling his anger and his honor, and in doing so, reconciles himself to his own mortality. He can now accept death, knowing that he will receive eternal fame. In addition, Achilles is reconciled to Agamemnon and the Greeks, and, at the
#
# The cleaned text is:
# {
#   "choices": [
#     {
#       "finish_reason": "stop",
#       "index": 0,
#       "message": {
#         "content": "The theme associated with war in Homer's epic poem The Iliad is that characters are judged based on their courage and ability in battle. The poem acknowledges the realities of war, such as death and destruction, but also portrays warfare as a respectable and even glorious way to settle disputes. In contrast, Erich Maria Remarque's novel All Quiet on the Western Front provides a contrasting view on war and its devastating effects. The Iliad also explores themes of love, friendship, fate, free will, and honor.\n\nAchilles, a central character in The Iliad, chooses to stay and fight in the Trojan War despite the fact that it will ultimately mean his death. He chooses to stay in order to earn honor and glory, which will live on after his death. Achilles' anger eventually leads to reconciliation. His anger is assuaged by the death of Patroklos and the return of his arms and honor. Achilles rejoins the war, reconciling his anger and his honor, and in doing so, reconciles himself to his own mortality. He can now accept death, knowing that he will receive eternal fame. Additionally, Achilles is reconciled to Agamemnon and the Greeks, and, at the same time, acknowledges the realities of war and its impact on individuals and societies.",
#         "role": "assistant"
#       }
#     }
#   ],
#   "created": 1678907227,
#   "id": "chatcmpl-6uQklulYObpSBwgK7akifiwWUgX9D",
#   "model": "gpt-3.5-turbo-0301",
#   "object": "chat.completion",
#   "usage": {
#     "completion_tokens": 265,
#     "prompt_tokens": 289,
#     "total_tokens": 554
#   }
# }
# The theme associated with war in Homer's epic poem The Iliad is that characters are judged based on their courage and ability in battle. The poem acknowledges the realities of war, such as death and destruction, but also portrays warfare as a respectable and even glorious way to settle disputes. In contrast, Erich Maria Remarque's novel All Quiet on the Western Front provides a contrasting view on war and its devastating effects. The Iliad also explores themes of love, friendship, fate, free will, and honor.
#
# Achilles, a central character in The Iliad, chooses to stay and fight in the Trojan War despite the fact that it will ultimately mean his death. He chooses to stay in order to earn honor and glory, which will live on after his death. Achilles' anger eventually leads to reconciliation. His anger is assuaged by the death of Patroklos and the return of his arms and honor. Achilles rejoins the war, reconciling his anger and his honor, and in doing so, reconciles himself to his own mortality. He can now accept death, knowing that he will receive eternal fame. Additionally, Achilles is reconciled to Agamemnon and the Greeks, and, at the same time, acknowledges the realities of war and its impact on individuals and societies.
# The theme associated with war in Homer's epic poem The Iliad is that characters are judged based on their courage and ability in battle. The poem acknowledges the realities of war, such as death and destruction, but also portrays warfare as a respectable and even glorious way to settle disputes. In contrast, Erich Maria Remarque's novel All Quiet on the Western Front provides a contrasting view on war and its devastating effects. The Iliad also explores themes of love, friendship, fate, free will, and honor.
#
# Achilles, a central character in The Iliad, chooses to stay and fight in the Trojan War despite the fact that it will ultimately mean his death. He chooses to stay in order to earn honor and glory, which will live on after his death. Achilles' anger eventually leads to reconciliation. His anger is assuaged by the death of Patroklos and the return of his arms and honor. Achilles rejoins the war, reconciling his anger and his honor, and in doing so, reconciles himself to his own mortality. He can now accept death, knowing that he will receive eternal fame. Additionally, Achilles is reconciled to Agamemnon and the Greeks, and, at the same time, acknowledges the realities of war and its impact on individuals and societies.
