# %%
# %%
import re
import httpx
import os
import openai
import gsearch
import slcindex
import callgpt


def open_file(filepath):
    with open(filepath, 'r', encoding='utf-8') as infile:
        return infile.read()


os.environ["OPENAI_API_KEY"] = open_file('Key/openai_api_key.txt')
openai.api_key = open_file('Key/openai_api_key.txt')
openai_api_key = openai.api_key


class ChatBot:
    def __init__(self, system=""):
        self.system = system
        self.messages = []
        if self.system:
            self.messages.append({"role": "system", "content": system})

    def __call__(self, message):
        self.messages.append({"role": "user", "content": message})
        result = self.execute()
        self.messages.append({"role": "assistant", "content": result})
        return result

    def execute(self):
        # chat = callgpt.Chat()
        # completion = chat.gpt_creative(self.messages)
        completion = openai.ChatCompletion.create(
            model="gpt-3.5-turbo", messages=self.messages)
        # Uncomment this to print out token usage each time, e.g.
        # {"completion_tokens": 86, "prompt_tokens": 26, "total_tokens": 112}
        # print(completion)
        # return completion
        return completion.choices[0].message.content


prompt = """
You run in a loop of Thought, Action, PAUSE, Observation.
At the end of the loop you output an Answer
Use Thought to describe your thoughts about the question you have been asked.
Use Action to run one of the actions available to you - then return PAUSE.
Observation will be the result of running those actions.

Your available actions are:

calculate:
e.g. calculate: 4 * 7 / 3
Runs a calculation and returns the number - uses Python so be sure to use floating point syntax if necessary

goog:
e.g. search for queries
If you don't know the answer to a query, searches Google via the function, which returns a summary of the results it found

wikipedia:
e.g. wikipedia: England
Returns a summary from searching Wikipedia

slc_search:
e.g. slc_search: Django
Search what Rohit wrote on Strange Loop Canon for "Django"

Always look things up on Wikipedia first, and only then expand to other sources.

Example session:
Question: What is the capital of France?
Thought: I should look up France on Wikipedia
Action: wikipedia: France
PAUSE

You will be called again with this:

Observation: France is a country. The capital is Paris.

You then output:

Answer: The capital of France is Paris

Example session:
Question: Where are the best pizza places in London?
Thought: I should look up pizza places in London
Action: goog: top pizza places
PAUSE

You will be called again with this:

Observation: In 2023, the best pizza places in London include Fatto a Mano in King's Cross, Flat Earth in Bethnal Green, and Happy Face in King's Cross. Fatto a Mano offers locally sourced Neapolitan-style pizzas.

You then output:

Answer: The best pizza in London is Fatto o Mano in Kings Cross
""".strip()


action_re = re.compile('^Action: (\w+): (.*)$')


def query(question, max_turns=2):
    i = 0
    results = []
    bot = ChatBot(prompt)
    next_prompt = question
    while i < max_turns:
        i += 1
        result = bot(next_prompt)
        print(result)
        actions = [action_re.match(a) for a in result.split(
            '\n') if action_re.match(a)]
        if actions:
            # There is an action to run
            action, action_input = actions[0].groups()
            if action not in known_actions:
                raise Exception(
                    "Unknown action: {}: {}".format(action, action_input))
            # print(" -- running {} {}".format(action, action_input))
            observation = known_actions[action](action_input)
            print("Observation:", observation)
            next_prompt = "Observation: {}".format(observation)
            return next_prompt
        else:
            return


def wikipedia(q):
    return httpx.get("https://en.wikipedia.org/w/api.php", params={
        "action": "query",
        "list": "search",
        "srsearch": q,
        "format": "json"
    }).json()["query"]["search"][0]["snippet"]


def slc_search(q):
    results = slcindex.inputquery(q)
    return results  # This line is just an example, you need to parse the actual results


def goog(q):
    return(gsearch.execute(q))

def calculate(what):
    return eval(what)


known_actions = {
    "wikipedia": wikipedia,
    "goog": goog,
    "calculate": calculate,
    "slc_search": slc_search
}


# ques = input("What do you want to know?")
query("How can you become a really good Venture Capitalist?")
# Out:
# Thought: To answer this question, I need to look up information about the skills and qualities required to become a successful venture capitalist.
# Action: goog: how to become a successful venture capitalist
# PAUSE
# ?
#
# 1. Venture Capitalist
# 2. Successful
# 3. Becoming
# 4. Strategies
# 5. Investing
# 6. Networking
# 7. Advice
# 8. Funding
# 9. Start-up
# 10. Entrepreneurship
# AIzaSyD96yzXpxfGkSJ-BJ_UcRxHs-6J1ldVQ5w
# 672d1d4528bca4a1a
# Page number isn't specified, defaulting to 1
# What are the steps to becoming a successful venture capitalist?
# https://www.googleapis.com/customsearch/v1?cx=672d1d4528bca4a1a&key=AIzaSyD96yzXpxfGkSJ-BJ_UcRxHs-6J1ldVQ5w&q=What are the steps to becoming a successful venture capitalist?&start=1
# [{'kind': 'customsearch#result', 'title': 'Being a Venture Capitalist: A How-to Guide', 'htmlTitle': '<b>Being a Venture Capitalist</b>: A How-to Guide', 'link': 'https://www.investopedia.com/articles/personal-finance/091415/howto-guide-being-venture-capitalist.asp', 'displayLink': 'www.investopedia.com', 'snippet': "It will take you at least seven to 10 years working in the financial sector before you can become a venture capitalist. You'll have to understand the ins and\xa0...", 'htmlSnippet': 'It will take you at least seven to 10 years working in the financial sector before you can <b>become a venture capitalist</b>. You&#39;ll have to understand the ins and&nbsp;...', 'cacheId': 'lJ9l_yIJfGUJ', 'formattedUrl': 'https://www.investopedia.com/.../howto-guide-being-venture-capitalist.asp', 'htmlFormattedUrl': 'https://www.investopedia.com/.../howto-guide-<b>being</b>-<b>venture</b>-<b>capitalist</b>.asp', 'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcTmR-IXCdWccriWu1dWahHBCL5ZpYlA6LeUvh-fkzQyeiHnl68xTQf9SGxw', 'width': '275', 'height': '183'}], 'metatags': [{'og:image': 'https://www.investopedia.com/thmb/tgfealmssSXz_i0CEmapTUxTkQk=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/GettyImages-815165952-e4c19c70555946fb8d40eecec865706e.jpg', 'twitter:card': 'summary', 'msapplication-square70x70logo': '/static/1.326.0/icons/favicons/mstile-70x70.png', 'sailthru.tags': 'investing,alternative-investments,private-equity-and-venture-cap', 'og:site_name': 'Investopedia', 'emailt1': 'Investing', 'msapplication-wide310x150logo': '/static/1.326.0/icons/favicons/mstile-310x150.png', 'msapplication-tileimage': '/static/1.326.0/icons/favicons/mstile-144x144.png', 'og:description': 'So you want to be a venture capitalist? Learn what it takes, where to start, and what kind of attitude you will need to take on the world of venture capitalism.', 'twitter:image': 'https://www.investopedia.com/thmb/tgfealmssSXz_i0CEmapTUxTkQk=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/GettyImages-815165952-e4c19c70555946fb8d40eecec865706e.jpg', 'twitter:site': '@Investopedia', 'msapplication-square310x310logo': '/static/1.326.0/icons/favicons/mstile-310x310.png', 'sailthru.title': 'Being a Venture Capitalist: A How-to Guide', 'emailcontenttype': 'STRUCTUREDCONTENT', 'msapplication-tilecolor': '#F4F4F4', 'sailthru.date': '2022-09-12T11:04:24.276Z', 'og:type': 'article', 'twitter:title': 'Being a Venture Capitalist: A How-to Guide', 'emailvertical': 'INVESTOPEDIA', 'og:title': 'Being a Venture Capitalist: A How-to Guide', 'msapplication-square150x150logo': '/static/1.326.0/icons/favicons/mstile-150x150.png', 'sailthru.image.thumb': 'https://www.investopedia.com/thmb/gEGt4WvM_RJtW-af4a5McqcRIT8=/255x165/filters:no_upscale()/GettyImages-815165952-e4c19c70555946fb8d40eecec865706e.jpg', 'fb:app_id': '659054097907801', 'viewport': 'width=device-width, initial-scale=1.0', 'twitter:description': 'So you want to be a venture capitalist? Learn what it takes, where to start, and what kind of attitude you will need to take on the world of venture capitalism.', 'og:url': 'https://www.investopedia.com/articles/personal-finance/091415/howto-guide-being-venture-capitalist.asp', 'sailthru.author': 'Dan Moskowitz'}], 'cse_image': [{'src': 'https://www.investopedia.com/thmb/tgfealmssSXz_i0CEmapTUxTkQk=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/GettyImages-815165952-e4c19c70555946fb8d40eecec865706e.jpg'}]}}, {'kind': 'customsearch#result', 'title': 'How to Become a Venture Capitalist (And What They Do) | Indeed ...', 'htmlTitle': 'How to <b>Become a Venture Capitalist</b> (And What They Do) | Indeed ...', 'link': 'https://ca.indeed.com/career-advice/career-development/how-to-become-a-venture-capitalist', 'displayLink': 'ca.indeed.com', 'snippet': 'Nov 12, 2022 ... 1. Gain relevant education. There are various academic approaches you can take to become a venture capitalist. · 3. Seek opportunitie ...
# Please clean up the following text:
#
# atics, and other areas.
#
# This article provides an overview of what it takes to become a venture capitalist. It explains that venture capitalists provide capital to young companies and startups with the potential for a high return on investment. It outlines the different paths to venture capitalism, such as being a true entrepreneur, an investment banker, a financial advisor, or an academic. It also explains that venture capitalists often use third-party assets to improve the efficacy of the company and that competition is stiff for access to This article discusses an error code (1020) that is preventing a user from accessing the site ca.indeed.com/career-advice/career-development/how-to-become-a-venture-capitalist. The article provides detailed information about the error, such as the Ray ID, country, data center, IP, and timestamp. The article suggests that the user provide this information to the site owner in order to gain access to the site. it’s time to get the money. Money will chase opportunity. If you’ve done a good job of the first three steps, you’ll have no trouble finding people to back you.
#
# Gaurav Jain explains how to become a venture capitalist without any capital. He outlines four distinct tasks: sourcing deals, diligence, negotiation, and financing. He emphasizes the importance of remaining honest throughout the process and suggests finding "Alpha geeks" at meetups and
#
# The cleaned text is:
# The ChatGPT cleaned up response is: This article provides an overview of how to become a venture capitalist. Venture capitalists invest in young companies and startups with high return potential. There are various pathways to venture capitalism, including being an entrepreneur, investment banker, financial advisor, or academic. Third-party assets are often used by venture capitalists to improve company efficacy, and competition for access to funding is fierce.
#
# The article also discusses error code 1020 that prevents access to the site ca.indeed.com/career-advice/career-development/how-to-become-a-venture-capitalist. The user should provide Ray ID, country, data center, IP, and timestamp to the site owner to resolve the issue.
#
# Gaurav Jain explains how to become a venture capitalist without any capital by sourcing deals, conducting diligence, negotiating, and financing. Honesty is essential throughout the process, and it can be helpful to find "Alpha geeks" at meetups. Money will follow opportunity if the preceding steps have been accomplished effectively.
# Observation: This article provides an overview of how to become a venture capitalist. Venture capitalists invest in young companies and startups with high return potential. There are various pathways to venture capitalism, including being an entrepreneur, investment banker, financial advisor, or academic. Third-party assets are often used by venture capitalists to improve company efficacy, and competition for access to funding is fierce.
#
# The article also discusses error code 1020 that prevents access to the site ca.indeed.com/career-advice/career-development/how-to-become-a-venture-capitalist. The user should provide Ray ID, country, data center, IP, and timestamp to the site owner to resolve the issue.
#
# Gaurav Jain explains how to become a venture capitalist without any capital by sourcing deals, conducting diligence, negotiating, and financing. Honesty is essential throughout the process, and it can be helpful to find "Alpha geeks" at meetups. Money will follow opportunity if the preceding steps have been accomplished effectively.
# 'Observation: This article provides an overview of how to become a venture capitalist. Venture capitalists invest in young companies and startups with high return potential. There are various pathways to venture capitalism, including being an entrepreneur, investment banker, financial advisor, or academic. Third-party assets are often used by venture capitalists to improve company efficacy, and competition for access to funding is fierce.\n\nThe article also discusses error code 1020 that prevents access to the site ca.indeed.com/career-advice/career-development/how-to-become-a-venture-capitalist. The user should provide Ray ID, country, data center, IP, and timestamp to the site owner to resolve the issue. \n\nGaurav Jain explains how to become a venture capitalist without any capital by sourcing deals, conducting diligence, negotiating, and financing. Honesty is essential throughout the process, and it can be helpful to find "Alpha geeks" at meetups. Money will follow opportunity if the preceding steps have been accomplished effectively.'
